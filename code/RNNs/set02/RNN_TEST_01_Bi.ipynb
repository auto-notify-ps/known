# %% [markdown]
# # []

# %%
# inbuilt 
import os
import sys
import math

# most common
import numpy as np
import matplotlib.pyplot as plt

# pytorch
import torch as tt
import torch.nn as nn
import torch.optim as oo
import torch.functional as ff
import torch.distributions as dd
import torch.utils.data as ud

# custom
import known
from known.basic import pj
from known.basic.common import Verbose as verb
import known.ktorch as kt

print(f'{sys.version=}\n{np.__version__=}\n{tt.__version__=}\n{known.__version__=}')
# Out:
# sys.version='3.8.10 (tags/v3.8.10:3d8993a, May  3 2021, 11:48:03) [MSC v.1928 64 bit (AMD64)]'
# np.__version__='1.22.2'
# tt.__version__='1.10.1+cu102'
# known.__version__='0.0.1'

# %% [markdown]
# # Select DataSet

# %% [markdown]
# ## (1) Sinus

# %%
seqlen = 10
cols = ('1','2', '3')
input_size = len(cols)

ds_test  = kt.SeqDataset.from_csv(pj('data_rnn/sinu.csv'), cols=cols, 
                seqlen=seqlen, reverse=True, normalize=False, squeeze_label=True, dtype=tt.float32)
ds_train = kt.SeqDataset.from_csv(pj('data_rnn/sinu_train.csv'), cols=cols, 
                seqlen=seqlen, reverse=True, normalize=False, squeeze_label=True, dtype=tt.float32)
ds_val = kt.SeqDataset.from_csv(pj('data_rnn/sinu_test.csv'), cols=cols, 
                seqlen=seqlen, reverse=True, normalize=False, squeeze_label=True, dtype=tt.float32)

ds_train, ds_val, ds_test
# Out:
# (<known.ktorch.data.SeqDataset at 0x196ffed4610>,
#  <known.ktorch.data.SeqDataset at 0x196ffe59c70>,
#  <known.ktorch.data.SeqDataset at 0x196ff48fee0>)

# %% [markdown]
# # (2) custom - g

# %%
seqlen = 25
cols = ('1','2')
input_size = len(cols)

ds_test  = kt.SeqDataset.from_csv(pj('data_rnn/g.csv'), cols=cols, 
                seqlen=seqlen, reverse=True, normalize=True, squeeze_label=True, dtype=tt.float32)
ds_train = kt.SeqDataset.from_csv(pj('data_rnn/g_train.csv'), cols=cols, 
                seqlen=seqlen, reverse=True, normalize=True, squeeze_label=True, dtype=tt.float32)
ds_val = kt.SeqDataset.from_csv(pj('data_rnn/g_test.csv'), cols=cols, 
                seqlen=seqlen, reverse=True, normalize=True, squeeze_label=True, dtype=tt.float32)

ds_train, ds_val, ds_test
# Out:
# (<known.ktorch.data.SeqDataset at 0x196a610abb0>,
#  <known.ktorch.data.SeqDataset at 0x196a610aca0>,
#  <known.ktorch.data.SeqDataset at 0x196a02887f0>)

# %% [markdown]
# # (3) custom - h

# %%
seqlen = 40
cols = ('1','2')
input_size = len(cols)

ds_test  = kt.SeqDataset.from_csv(pj('data_rnn/h.csv'), cols=cols, 
                seqlen=seqlen, reverse=True, normalize=True, squeeze_label=True, dtype=tt.float32)
ds_train = kt.SeqDataset.from_csv(pj('data_rnn/h_train.csv'), cols=cols, 
                seqlen=seqlen, reverse=True, normalize=True, squeeze_label=True, dtype=tt.float32)
ds_val = kt.SeqDataset.from_csv(pj('data_rnn/h_test.csv'), cols=cols, 
                seqlen=seqlen, reverse=True, normalize=True, squeeze_label=True, dtype=tt.float32)

ds_train, ds_val, ds_test
# Out:
# (<known.ktorch.data.SeqDataset at 0x196a610a5b0>,
#  <known.ktorch.data.SeqDataset at 0x196a02d66d0>,
#  <known.ktorch.data.SeqDataset at 0x196ffec0640>)

# %% [markdown]
# # Define Regression Network

# %%
dt = tt.float32
dropout=0.0
batch_first = True
num_layers = 2
hidden_size = 32
bidirectional = False
bias = True
nonlinearity='tanh'

hidden_sizes = [hidden_size for _ in range(num_layers)]
stack_output=True
use_rnn=False

class RNNRegression(nn.Module):
    def __init__(self, rnn, output_size) -> None:
        super().__init__()
        self.rnn = kt.BiRNN(rnn)
        self.fc = nn.Linear(output_size*2, rnn.input_size)

    def forward(self, X):
        x1,x2 = self.rnn(X)
        return self.fc(tt.cat((x1, x2), dim=-1))

# %% [markdown]
# ## encapsulate rnns

# %%
networks = dict(

elman_kt = RNNRegression(kt.ELMAN(
        input_size=input_size,      
        i2h_sizes=hidden_sizes,      
        i2o_sizes=None,  
        o2o_sizes=None,  
        dropout=0.0,        
        batch_first=batch_first,  
        stack_output=stack_output, 
        i2h_bias = bias, 
        i2o_bias = True,
        o2o_bias = True,
        i2h_activations=(),
        i2o_activation=None,
        o2o_activation=None,
        last_activation=None,
        hypers=None,
        return_last=True,
        return_hidden=False,
        dtype=dt,
        device=None),
    output_size = hidden_size),

gru_kt = RNNRegression(kt.GRU(
        input_size=input_size,      
        i2h_sizes=hidden_sizes,      
        i2o_sizes=None,  
        o2o_sizes=None,  
        dropout=0.0,        
        batch_first=batch_first,  
        stack_output=stack_output, 
        i2h_bias = bias, 
        i2o_bias = True,
        o2o_bias = True,
        i2h_activations=(),
        i2o_activation=None,
        o2o_activation=None,
        last_activation=None,
        hypers=None,
        return_last=True,
        return_hidden=False,
        dtype=dt,
        device=None),
    output_size = hidden_size),

lstm_kt = RNNRegression(kt.LSTM(
        input_size=input_size,      
        i2h_sizes=hidden_sizes,      
        i2o_sizes=None,  
        o2o_sizes=None,  
        dropout=0.0,        
        batch_first=batch_first,  
        stack_output=stack_output, 
        i2h_bias = bias, 
        i2o_bias = True,
        o2o_bias = True,
        i2h_activations=(),
        i2o_activation=None,
        o2o_activation=None,
        last_activation=None,
        hypers=None,
        return_last=True,
        return_hidden=False,
        dtype=dt,
        device=None),
    output_size = hidden_size),

mgu_kt = RNNRegression(kt.MGU(
        input_size=input_size,      
        i2h_sizes=hidden_sizes,      
        i2o_sizes=None,  
        o2o_sizes=None,  
        dropout=0.0,        
        batch_first=batch_first,  
        stack_output=stack_output, 
        i2h_bias = bias, 
        i2o_bias = True,
        o2o_bias = True,
        i2h_activations=(),
        i2o_activation=None,
        o2o_activation=None,
        last_activation=None,
        hypers=None,
        return_last=True,
        return_hidden=False,
        dtype=dt,
        device=None),
    output_size = hidden_size),

janet_kt = RNNRegression(kt.JANET(
        input_size=input_size,      
        i2h_sizes=hidden_sizes,      
        i2o_sizes=None,  
        o2o_sizes=None,  
        dropout=0.0,        
        batch_first=batch_first,  
        stack_output=stack_output, 
        i2h_bias = bias, 
        i2o_bias = True,
        o2o_bias = True,
        i2h_activations=(),
        i2o_activation=None,
        o2o_activation=None,
        last_activation=None,
        hypers=None,
        return_last=True,
        return_hidden=False,
        dtype=dt,
        device=None),
    output_size = hidden_size),

)

colors = {k:v for k,v in zip(networks.keys(), \
            [ 'tab:red', 'tab:blue', 'tab:green', 'tab:orange', 'tab:brown' ])}

# %% [markdown]
# # (A) Train and Evaluate

# %%
test_loss, train_loss = {}, {}
for key,model in networks.items():
    print(key, model.__class__)
    epochs = 500
    batch_size=32
    shuffle=True
    validation_freq = int(epochs/10)
    criterion=nn.MSELoss()
    lr = 0.0025
    weight_decay = 0.0
    optimizer=oo.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    lrs=oo.lr_scheduler.LinearLR(optimizer, start_factor= 1.0, end_factor=0.7, total_iters=epochs)

    early_stop_train=kt.QuantiyMonitor('TrainLoss', patience=50, delta=0.00001)
    early_stop_val=kt.QuantiyMonitor('ValLoss', patience=50, delta=0.00001)
    #checkpoint_freq=int(epochs/4)
    save_path=f'{key}.reg'
    loss_plot_start = int(epochs/50)

    trainer = kt.Trainer(model)
    trainer.optimizer=optimizer
    trainer.criterion=criterion

    trainer.fit(training_data=ds_train, validation_data=ds_val, 
                epochs=epochs, batch_size=batch_size,shuffle=shuffle,validation_freq=validation_freq,
                save_path=save_path, use_rnn=use_rnn, verbose=1)

    trainer.plot_results(color=colors[key],loss_plot_start=loss_plot_start)

    mtl, _ = trainer.evaluate(ds_test, batch_size=None, use_rnn=use_rnn)
    train_loss[key] = np.array(trainer.train_loss_history)
    test_loss[key] = mtl
    print('=================================================')
    
plt.figure(figsize=(16,8))
for k,v in train_loss.items():
    plt.plot(np.mean(v, axis=1)[loss_plot_start:], label=k, color=colors[k], linewidth=0.8)
plt.legend()
plt.show()
# Out:
# elman_kt <class '__main__.RNNRegression'>
# Training samples: [310]
# Training batches: [10]
# Validation samples: [110]
# Validation batches: [1]
# Start Training @ 2023-01-24 02:47:19.618268
# -------------------------------------------
# [*] Saved@ elman_kt.reg
# -------------------------------------------
# Final Training Loss: [3.011939561474719e-05]
# Final Validation Loss: [3.1802774174138904e-05]
# End Training @ 2023-01-24 02:48:49.697759, Elapsed Time: [0:01:30.079491]
# Testing samples: [460]
# Testing batches: [1]
# Testing Loss: 9.014522947836667e-05
# =================================================
# gru_kt <class '__main__.RNNRegression'>
# Training samples: [310]
# Training batches: [10]
# Validation samples: [110]
# Validation batches: [1]
# Start Training @ 2023-01-24 02:48:49.908760
# -------------------------------------------
# [*] Saved@ gru_kt.reg
# -------------------------------------------
# Final Training Loss: [3.4522361238487066e-05]
# Final Validation Loss: [0.00016541342483833432]
# End Training @ 2023-01-24 02:54:03.238134, Elapsed Time: [0:05:13.329374]
# Testing samples: [460]
# Testing batches: [1]
# Testing Loss: 0.00015861180145293474
# =================================================
# lstm_kt <class '__main__.RNNRegression'>
# Training samples: [310]
# Training batches: [10]
# Validation samples: [110]
# Validation batches: [1]
# Start Training @ 2023-01-24 02:54:03.523656
# -------------------------------------------
# [*] Saved@ lstm_kt.reg
# -------------------------------------------
# Final Training Loss: [7.00656386470655e-05]
# Final Validation Loss: [0.001079091802239418]
# End Training @ 2023-01-24 02:59:51.646118, Elapsed Time: [0:05:48.122462]
# Testing samples: [460]
# Testing batches: [1]
# Testing Loss: 0.0008247444638982415
# =================================================
# mgu_kt <class '__main__.RNNRegression'>
# Training samples: [310]
# Training batches: [10]
# Validation samples: [110]
# Validation batches: [1]
# Start Training @ 2023-01-24 02:59:51.935160
# -------------------------------------------
# [*] Saved@ mgu_kt.reg
# -------------------------------------------
# Final Training Loss: [3.134279977530241e-05]
# Final Validation Loss: [0.00025820228620432317]
# End Training @ 2023-01-24 03:03:54.445163, Elapsed Time: [0:04:02.510003]
# Testing samples: [460]
# Testing batches: [1]
# Testing Loss: 5.178610808798112e-05
# =================================================
# janet_kt <class '__main__.RNNRegression'>
# Training samples: [310]
# Training batches: [10]
# Validation samples: [110]
# Validation batches: [1]
# Start Training @ 2023-01-24 03:03:54.663399
# -------------------------------------------
# [*] Saved@ janet_kt.reg
# -------------------------------------------
# Final Training Loss: [3.363081723364303e-05]
# Final Validation Loss: [0.0007190094911493361]
# End Training @ 2023-01-24 03:07:56.516020, Elapsed Time: [0:04:01.852621]
# Testing samples: [460]
# Testing batches: [1]
# Testing Loss: 0.00047269734204746783
# =================================================

# %% [markdown]
# # (B) Load and Evaluate

# %%
for key,model in networks.items():
    kt.load_state(model, f'{key}.reg')
test_loss={}

for key,model in networks.items():
    trainer = kt.Trainer(model)
    trainer.criterion=nn.MSELoss() 
    mtl, tl = trainer.evaluate(ds_test, use_rnn=use_rnn)

    test_loss[key] = mtl
# Out:
# Testing samples: [460]
# Testing batches: [1]
# Testing Loss: 9.014522947836667e-05
# Testing samples: [460]
# Testing batches: [1]
# Testing Loss: 0.00015861180145293474
# Testing samples: [460]
# Testing batches: [1]
# Testing Loss: 0.0008247444638982415
# Testing samples: [460]
# Testing batches: [1]
# Testing Loss: 5.178610808798112e-05
# Testing samples: [460]
# Testing batches: [1]
# Testing Loss: 0.00047269734204746783

# %% [markdown]
# # Plot Evaluation Results

# %%
y = []
l = []
c = []
for k,v in test_loss.items():
    print(f'{k}:\t{v}')
    y.append(v)
    l.append(k)
    c.append(colors[k])

x= range(len(test_loss))

y = np.array(y)
l = np.array(l)
t = np.argsort(y)

plt.figure(figsize=(20,6))
plt.xlim(-1,len(x))
plt.ylim(0,0.001)
for i in t:
    plt.bar([i] , y[t[i]], color=c[t[i]] )
    plt.hlines(y[t[i]], -1, i, linestyles='solid', linewidth=0.5, color=c[t[i]])
plt.xticks(x, l[t])
plt.ylabel('val_loss')
plt.show()
# Out:
# elman_kt:	9.014522947836667e-05
# gru_kt:	0.00015861180145293474
# lstm_kt:	0.0008247444638982415
# mgu_kt:	5.178610808798112e-05
# janet_kt:	0.00047269734204746783

# %% [markdown]
# # Manual Testing

# %% [markdown]
# ## test dataset

# %%
res = {}
for key,model in networks.items():
    print(key, model.__class__)
    model.eval()
    with tt.no_grad():
        dl = iter(ds_test.dataloader(batch_size=int(len(ds_test)*1.0)))
        Xv, Yv = next(dl)
        Pv = model(Xv)
        res[key]=Pv #print(Xv.shape, Yv.shape, Pv.shape)
# Out:
# elman_kt <class '__main__.RNNRegression'>
# gru_kt <class '__main__.RNNRegression'>
# lstm_kt <class '__main__.RNNRegression'>
# mgu_kt <class '__main__.RNNRegression'>
# janet_kt <class '__main__.RNNRegression'>

# %% [markdown]
# ## visualize

# %%
for i in range(input_size):
    plt.figure(figsize=(20,10))
    plt.title(f'{i}')
    
    plt.plot(Yv[:,i], color='black', label='Truth')
    for key,r in res.items():
        plt.plot(r[:,i], color=colors[key], label=f'{key}', linewidth=0.5)
    plt.legend()
    plt.show()
    plt.close()
    print('=================================================')
# Out:
# =================================================
# =================================================
